# %%
a = input("Enter a string:")
# Out:
# Enter a string:Mahesh

# %%
rev = a[::-1]
if a == rev:
    print("Palindrome")
else: 
    print("Not a palindrome")
# Out:
# Palindrome

# %%
b = "".join(reversed(a))
b
# Out:
# 'hsehaM'

# %%
a = "Another random string"

# print(a[4])
# print(a[-1])
# print(a[4:])
# print(a[:4])
# print(a[4:9])
# print(a[:-1])
# print(a[-10:-6])
a[1:-1]
# Out:
# 'nother random strin'
