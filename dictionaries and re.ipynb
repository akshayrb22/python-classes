# %%
dict1 = {"Name": "Akshay", "Place": "California", "Year": 2020}

# %%
print(dict1["Name"])
# Out:
# Akshay

# %%
for x in dict1:
    print(x)
# Out:
# Name
# Place
# Year

# %%
for x in dict1:
    print(dict1[x])
# Out:
# Akshay
# California
# 2020

# %%
for x in dict1.values():
    print(x)
# Out:
# Akshay
# California
# 2020

# %%
for x, y in dict1.items():
    print(x, y)
# Out:
# Name Akshay
# Place California
# Year 2020

# %%
print(len(dict1))
# Out:
# 3

# %%
dict1.pop("Year")
# Out:
# 2020

# %%
type(dict1.popitem())
# Out:
# tuple

# %%
del dict1

# %%
_
# Out:
# tuple

# %%
dict2 = {"Name": "Akshay", "Place": "California", "Year": 2020}

# %%
import re

# %%
p = re.compile('ab*')
print(p)
# Out:
# re.compile('ab*')

# %%
s = "Akshay went to California"

# %%
x = re.findall("a", s, re.IGNORECASE)
print(x)
# Out:
# ['A', 'a', 'a', 'a']

# %%
print(re.search('shay', s))
# Out:
# <re.Match object; span=(2, 6), match='shay'>

# %%
re.findall("Aks", s)
# Out:
# ['Aks']

# %%
re.split("j", "Sanjay")
# Out:
# ['San', 'ay']

# %%
re.sub("n", "j", "Sanjay")
# Out:
# 'Sajjay'

# %%
import re
re.sub("hesh", "gauthami", "mahesh")
# Out:
# 'magauthami'

# %% [markdown]
# [] indicates a set of characters, {} indicates repitition, \d indicates digits

# %%
s = "This is a different string. Fair review."
x = re.findall("^T", s)
x
# Out:
# ['T']

# %%
x = re.findall("2", s)
print(x)
# Out:
# []

# %%
x = re.findall('[0-9]', s)
x
# Out:
# []

# %%
x = re.match("ai+", s)
print(x)
# Out:
# None

# %%
x = re.findall("[a-m]", s)
x
# Out:
# ['h',
#  'i',
#  'i',
#  'a',
#  'd',
#  'i',
#  'f',
#  'f',
#  'e',
#  'e',
#  'i',
#  'g',
#  'a',
#  'i',
#  'e',
#  'i',
#  'e']

# %%
x = re.findall("^[a-z]", s)
x
# Out:
# []
